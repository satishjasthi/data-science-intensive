# %%
# %matplotlib inline
import pandas as pd

# %%
'''from IPython.core.display import HTML
css = open('style-table.css').read() + open('style-notebook.css').read()
HTML('<style>{}</style>'.format(css))'''
# Out:
# "from IPython.core.display import HTML\ncss = open('style-table.css').read() + open('style-notebook.css').read()\nHTML('<style>{}</style>'.format(css))"

# %%
titles = pd.DataFrame.from_csv('data/titles.csv', index_col=None)
titles.tail()
# Out:
#                         title  year
# 216531  Nobody Waved Good-bye  1964
# 216532                  E yue  2005
# 216533           Lakota Girls  2015
# 216534         Kroniki domowe  1997
# 216535           The Sting II  1983

# %%
cast = pd.DataFrame.from_csv('data/cast.csv', index_col=None)
cast.head()
# Out:
#                                title  year       name   type character   n
# 0                    Suuri illusioni  1985     Homo $  actor    Guests  22
# 1     Gangsta Rap: The Glockumentary  2007  Too $hort  actor   Himself NaN
# 2                  Menace II Society  1993  Too $hort  actor   Lew-Loc  27
# 3  Porndogs: The Adventures of Sadie  2009  Too $hort  actor     Bosco   3
# 4                 Stop Pepper Palmer  2014  Too $hort  actor   Himself NaN

# %% [markdown]
# ### How many movies are listed in the titles dataframe?

# %%
len(titles)
# Out:
# 216536

# %% [markdown]
# ### What are the earliest two films listed in the titles dataframe?

# %%
titles.sort_values('year').head(2)
# Out:
#                                                     title  year
# 165628                                         Miss Jerry  1894
# 85967   Reproduction of the Corbett and Fitzsimmons Fight  1897

# %% [markdown]
# ### How many movies have the title "Hamlet"?

# %%
hamlets = titles[titles.title == 'Hamlet']
hamlets
# Out:
#          title  year
# 5572    Hamlet  1948
# 26218   Hamlet  2016
# 37483   Hamlet  2015
# 42348   Hamlet  1990
# 43621   Hamlet  1910
# 68452   Hamlet  1954
# 86001   Hamlet  1976
# 88032   Hamlet  1987
# 88225   Hamlet  2000
# 91989   Hamlet  1921
# 114512  Hamlet  1969
# 155033  Hamlet  1913
# 164076  Hamlet  2009
# 170470  Hamlet  1964
# 187517  Hamlet  1996
# 193332  Hamlet  2011
# 195542  Hamlet  1911
# 206385  Hamlet  1973
# 208347  Hamlet  2014

# %%
len(hamlets)
# Out:
# 19

# %% [markdown]
# ### How many movies are titled "North by Northwest"?

# %%
nnw = titles[titles.title == "North by Northwest"]
nnw
# Out:
#                      title  year
# 129864  North by Northwest  1959

# %%
len(nnw)
# Out:
# 1

# %% [markdown]
# ### When was the first movie titled "Hamlet" made?

# %%
hamlets.sort_values('year')
# Out:
#          title  year
# 43621   Hamlet  1910
# 195542  Hamlet  1911
# 155033  Hamlet  1913
# 91989   Hamlet  1921
# 5572    Hamlet  1948
# 68452   Hamlet  1954
# 170470  Hamlet  1964
# 114512  Hamlet  1969
# 206385  Hamlet  1973
# 86001   Hamlet  1976
# 88032   Hamlet  1987
# 42348   Hamlet  1990
# 187517  Hamlet  1996
# 88225   Hamlet  2000
# 164076  Hamlet  2009
# 193332  Hamlet  2011
# 208347  Hamlet  2014
# 37483   Hamlet  2015
# 26218   Hamlet  2016

# %%
hamlets.sort_values('year').head(1)
# Out:
#         title  year
# 43621  Hamlet  1910

# %% [markdown]
# ### List all of the "Treasure Island" movies from earliest to most recent.

# %%
titles[titles.title == "Treasure Island"].sort_values('year')
# Out:
#                   title  year
# 191892  Treasure Island  1918
# 47866   Treasure Island  1920
# 193429  Treasure Island  1934
# 90437   Treasure Island  1950
# 213589  Treasure Island  1972
# 103921  Treasure Island  1973
# 191299  Treasure Island  1985
# 167148  Treasure Island  1999

# %% [markdown]
# ### How many movies were made in the year 1950?

# %%
len(titles[titles.year == 1950])
# Out:
# 1038

# %%
titles[titles.year == 1950]
# Out:
#                                                     title  year
# 89                                       Botta e risposta  1950
# 520                                   Un certain monsieur  1950
# 953                                     Vom Teufel gejagt  1950
# 1052                                          The Jackpot  1950
# 1237                                 This Side of the Law  1950
# 1329                                            The Actor  1950
# 1466                                  Tanssi yli hautojen  1950
# 1574                                 Akatsuki no tsuiseki  1950
# 1623                                Atom Man vs. Superman  1950
# 1736                                 The Sun Sets at Dawn  1950
# 1823                                    Paolo e Francesca  1950
# 2096                                   Annie Get Your Gun  1950
# 2451                                     O Pecado de Nina  1950
# 2650                                   Hit Parade of 1951  1950
# ...

# %% [markdown]
# ### How many movies were made in the year 1960?

# %%
titles[titles.year == 1960]
# Out:
#                                   title  year
# 104                     Cone of Silence  1960
# 239                     Magavari Mayalu  1960
# 314                       The Challenge  1960
# 429             Dos hijos desobedientes  1960
# 432                            Nianchan  1960
# 817                    Pretty Boy Floyd  1960
# 844                   Caught in the Net  1960
# 951                 Un militare e mezzo  1960
# 1181                           Fortunat  1960
# 1277                        Cheoljomang  1960
# 1631                 Un dollaro di fifa  1960
# 1639                   Pote tin Kyriaki  1960
# 1714                   Scent of Mystery  1960
# 2026                    Jiao feng ye yu  1960
# 2075                         Isi neraka  1960
# 2084                Outside the Kulambo  1960
# 2146                 Le bal des espions  1960
# 2200                      Ku hai gu chu  1960
# 2322                    Doon Pa sa Amin  1960
# ...

# %%
len(titles[titles.year == 1960])
# Out:
# 1473

# %% [markdown]
# ### How many movies were made from 1950 through 1959?

# %%
fifties = titles[(titles.year >= 1950) & (titles.year <= 1959)]
fifties
# Out:
#                                          title  year
# 8                               Women's Prison  1955
# 40      La momia azteca contra el robot humano  1958
# 45                                 Mavi boncuk  1958
# 62                     Radar Men from the Moon  1952
# 89                            Botta e risposta  1950
# 91                         Perdeu-se um Marido  1957
# 111                             Qiu yu can hua  1953
# 113                                 Hi no tori  1956
# 127                            Rock Rock Rock!  1956
# 130                           Quem Sabe, Sabe!  1956
# 162                            Yin shen nu xia  1957
# 202                            Next to No Time  1958
# 242                           Pardon My French  1951
# 255                         Pelli Chesi Choodu  1952
# 304                                    Ukikusa  1959
# 400                      Prisionera del pasado  1954
# 446                      The Lost Class of '59  1959
# ...

# %%
len(fifties)
# Out:
# 12175

# %% [markdown]
# ### In what years has a movie titled "Batman" been released?

# %%
titles[titles.title == "Batman"].year
# Out:
# 52270    1989
# 69682    1943
# Name: year, dtype: int64

# %% [markdown]
# ### How many roles were there in the movie "Inception"?

# %%
cast = pd.DataFrame.from_csv('data/cast.csv', index_col=None)
cast.head()
# Out:
#                                title  year       name   type character   n
# 0                    Suuri illusioni  1985     Homo $  actor    Guests  22
# 1     Gangsta Rap: The Glockumentary  2007  Too $hort  actor   Himself NaN
# 2                  Menace II Society  1993  Too $hort  actor   Lew-Loc  27
# 3  Porndogs: The Adventures of Sadie  2009  Too $hort  actor     Bosco   3
# 4                 Stop Pepper Palmer  2014  Too $hort  actor   Himself NaN

# %%
len(cast[cast.title == "Inception"])
# Out:
# 75

# %% [markdown]
# ### How many roles in the movie "Inception" are NOT ranked by an "n" value?

# %%
len(cast[(cast.title == "Inception") & cast.n.isnull()])
# Out:
# 24

# %%
cast[(cast.title == "Inception") & cast.n.isnull()]
# Out:
#              title  year                     name     type  \
# 87509    Inception  2010     Michael (III) August    actor
# 177529   Inception  2010                 Ken Bhan    actor
# 338650   Inception  2010            John Ceallach    actor
# 620017   Inception  2010            Seve Esposito    actor
# 641396   Inception  2010  Zachary Christopher Fay    actor
# 758206   Inception  2010        Daniel Girondeaud    actor
# 913778   Inception  2010          Andrew Hoagland    actor
# 994430   Inception  2010          Charles Jarrell    actor
# 1006517  Inception  2010            Seong-hwan Jo    actor
# 1016854  Inception  2010          Alonzo F. Jones    actor
# 1078707  Inception  2010               Mobin Khan    actor
# 1131343  Inception  2010            Shunsaku Kud?    actor
# 1174627  Inception  2010         John (IX) Lawson    actor
# 1189210  Inception  2010    Jean-Christophe Leger    actor
# 1510792  Inception  2010     Fran?ois-Marie Nivon    actor
# ...

# %% [markdown]
# ### But how many roles in the movie "Inception" did receive an "n" value?

# %%
inceptioners = cast[(cast.title == "Inception") & (cast.n.notnull())]
inceptioners
# Out:
#              title  year                  name     type  \
# 133222   Inception  2010          Peter Basham    actor
# 164939   Inception  2010          Tom Berenger    actor
# 233897   Inception  2010        Virgile Bramly    actor
# 294940   Inception  2010         Michael Caine    actor
# 301065   Inception  2010          Earl Cameron    actor
# 391751   Inception  2010         Nicolas Clerc    actor
# 401470   Inception  2010        Adam (IV) Cole    actor
# 468468   Inception  2010    Jean-Michel Dagory    actor
# 535035   Inception  2010     Leonardo DiCaprio    actor
# 642982   Inception  2010             Russ Fega    actor
# 668500   Inception  2010      Mark Fleischmann    actor
# 732633   Inception  2010        Michael Gaston    actor
# 736493   Inception  2010       Johnathan Geare    actor
# 754335   Inception  2010         Carl Gilliard    actor
# 755544   Inception  2010           Jack Gilroy    actor
# 779602   Inception  2010  Joseph Gordon-Levitt    actor
# ...

# %%
len(inceptioners)
# Out:
# 51

# %% [markdown]
# ### Display the cast of "North by Northwest" in their correct "n"-value order, ignoring roles that did not earn a numeric "n" value.

# %%
cast[(cast.title == "North by Northwest") & (cast.n.notnull())].sort_values('n')
# Out:
#                       title  year                  name     type  \
# 789998   North by Northwest  1959            Cary Grant    actor
# 3154749  North by Northwest  1959       Eva Marie Saint  actress
# 1320849  North by Northwest  1959           James Mason    actor
# 2838948  North by Northwest  1959   Jessie Royce Landis  actress
# 322299   North by Northwest  1959        Leo G. Carroll    actor
# 2745218  North by Northwest  1959  Josephine Hutchinson  actress
# 1537502  North by Northwest  1959           Philip Ober    actor
# 1155311  North by Northwest  1959         Martin Landau    actor
# 2215991  North by Northwest  1959         Adam Williams    actor
# 1642042  North by Northwest  1959          Edward Platt    actor
# 603354   North by Northwest  1959     Robert Ellenstein    actor
# 2078797  North by Northwest  1959          Les Tremayne    actor
# 420250   North by Northwest  1959       Philip Coolidge    actor
# ...

# %% [markdown]
# ### Display the entire cast, in "n"-order, of the 1972 film "Sleuth".

# %%
cast[(cast.title == "Sleuth") & (cast.year == 1972)].sort_values('n')
# Out:
#           title  year                name     type  \
# 1546535  Sleuth  1972    Laurence Olivier    actor
# 294969   Sleuth  1972       Michael Caine    actor
# 337971   Sleuth  1972      Alec Cawthorne    actor
# 1328287  Sleuth  1972  John (II) Matthews    actor
# 2460569  Sleuth  1972  Eve (III) Channing  actress
# 1313271  Sleuth  1972        Teddy Martin    actor
#
#                           character  n
# 1546535                 Andrew Wyke  1
# 294969                  Milo Tindle  2
# 337971            Inspector Doppler  3
# 1328287  Detective Sergeant Tarrant  4
# 2460569             Marguerite Wyke  5
# 1313271      Police Constable Higgs  6

# %% [markdown]
# ### Now display the entire cast, in "n"-order, of the 2007 version of "Sleuth".

# %%
cast[(cast.title == "Sleuth") & (cast.year == 2007)].sort_values('n')
# Out:
#           title  year                 name     type          character   n
# 294970   Sleuth  2007        Michael Caine    actor             Andrew   1
# 1172161  Sleuth  2007             Jude Law    actor               Milo   2
# 1637144  Sleuth  2007        Harold Pinter    actor        Man on T.V.   3
# 233996   Sleuth  2007      Kenneth Branagh    actor  Other Man on T.V. NaN
# 337972   Sleuth  2007  Alec (II) Cawthorne    actor  Inspector Doppler NaN
# 2460568  Sleuth  2007    Eve (II) Channing  actress    Marguerite Wyke NaN
# 3025835  Sleuth  2007    Carmel O'Sullivan  actress             Maggie NaN

# %% [markdown]
# ### How many roles were credited in the silent 1921 version of Hamlet?

# %%
hamlets = cast[(cast.title == "Hamlet") & (cast.year == 1921) & (cast.n.notnull())]
hamlets
# Out:
#           title  year                    name     type         character  n
# 6826     Hamlet  1921        Fritz Achterberg    actor       Fortinbras,  9
# 414828   Hamlet  1921            Paul Conradi    actor      K?nig Hamlet  2
# 502963   Hamlet  1921        Anton De Verdier    actor           Laertes  7
# 1030355  Hamlet  1921         Hans Junkermann    actor          Polonius  6
# 1979622  Hamlet  1921            Heinz Stieda    actor           Horatio  5
# 2150691  Hamlet  1921  Eduard von Winterstein    actor          Claudius  4
# 2407747  Hamlet  1921         Mathilde Brandt  actress  K?nigin Gertrude  3
# 2756997  Hamlet  1921          Lilly Jacobson  actress           Ophelia  8
# 3012392  Hamlet  1921            Asta Nielsen  actress            Hamlet  1

# %%
len(hamlets)
# Out:
# 9

# %% [markdown]
# ### How many roles were credited in Branagh’s 1996 Hamlet?

# %%
len(cast[(cast.title == "Hamlet") & (cast.year == 1996) & (cast.n.notnull())])
# Out:
# 46

# %% [markdown]
# ### How many "Hamlet" roles have been listed in all film credits through history?

# %%
len(cast[cast.character == "Hamlet"])
# Out:
# 85

# %% [markdown]
# ### How many people have played an "Ophelia"?

# %%
uniques = set(cast[cast.character == "Ophelia"].name)

# %%
len(uniques)
# Out:
# 97

# %% [markdown]
# ### How many people have played a role called "The Dude"?

# %%
dudes = cast[cast.character == "The Dude"].name
dudes
# Out:
# 244911            Jeff Bridges
# 306518             Jordan Cann
# 451612           Scott Crowell
# 516657          Chris DeMarcus
# 553251             Mike Donlin
# 570475          Devin The Dude
# 989397     Matthew (XIX) James
# 1033579     Christopher Kadish
# 1239070       Jason Loughridge
# 1256738            Steve Lyons
# 1371915         Mark Alan Meek
# 1397617            Jerry Miley
# 1617721       House Peters Jr.
# 1666993        Jason Priestley
# 1994883           Bobby Styles
# 2114929        Dick Van Patten
# 2190305             Joel Weiss
# Name: name, dtype: object

# %%
len(dudes)
# Out:
# 17

# %% [markdown]
# ### How many people have played a role called "The Stranger"?

# %%
strangers = cast[cast.character == "The Stranger"]
strangers
# Out:
#                                               title  year  \
# 22938                                         Theeb  2014
# 31788                                My Time to Die  2014
# 59979                                      Get Mean  1975
# 59982                      Lo straniero di silenzio  1968
# 59984                        Un dollaro tra i denti  1967
# 59985              Un uomo, un cavallo, una pistola  1967
# 74013                   Buzzy and the Phantom Pinto  1941
# 110715                                   Hungry Man  2013
# 125094                               Trading Hearts  1988
# 126926                             The Gospel of Us  2012
# 132842                                      Winning  1969
# 179718                                Urban Odyssey  2010
# 187693                               Suit of Lights  2014
# 217299                              Land o' Lizards  1916
# 237597                    Im Banne des Unheimlichen  1968
# ...

# %%
len(strangers)
# Out:
# 194

# %% [markdown]
# ### How many roles has Sidney Poitier played throughout his career?

# %%
poitiers = cast[cast.name == "Sidney Poitier"]
poitiers
# Out:
#                                 title  year            name   type  \
# 1646411               A Patch of Blue  1965  Sidney Poitier  actor
# 1646412         A Piece of the Action  1977  Sidney Poitier  actor
# 1646413           A Raisin in the Sun  1961  Sidney Poitier  actor
# 1646414               A Warm December  1973  Sidney Poitier  actor
# 1646415             All the Young Men  1960  Sidney Poitier  actor
# 1646416                Band of Angels  1957  Sidney Poitier  actor
# 1646417             Blackboard Jungle  1955  Sidney Poitier  actor
# 1646418                  Brother John  1971  Sidney Poitier  actor
# 1646419         Buck and the Preacher  1972  Sidney Poitier  actor
# 1646420      Cry, the Beloved Country  1951  Sidney Poitier  actor
# 1646421                Duel at Diablo  1966  Sidney Poitier  actor
# 1646422              Edge of the City  1957  Sidney Poitier  actor
# 1646423               For Love of Ivy  1968  Sidney Poitier  actor
# ...

# %%
len(poitiers)
# Out:
# 43

# %% [markdown]
# ### How many roles has Judi Dench played?

# %%
denches = cast[cast.name == "Judi Dench"]
denches
# Out:
#                                                title  year        name  \
# 2539418                        84 Charing Cross Road  1987  Judi Dench
# 2539419                            A Handful of Dust  1988  Judi Dench
# 2539420                    A Midsummer Night's Dream  1968  Judi Dench
# 2539421                           A Room with a View  1985  Judi Dench
# 2539422                            A Study in Terror  1965  Judi Dench
# 2539423       Angelina Ballerina: Angelina Sets Sail  2006  Judi Dench
# 2539424                                Casino Royale  2006  Judi Dench
# 2539425                                     Chocolat  2000  Judi Dench
# 2539426                                    Dead Cert  1974  Judi Dench
# 2539427                              Die Another Day  2002  Judi Dench
# 2539428                                       Doogal  2006  Judi Dench
# 2539429                          Four in the Morning  1965  Judi Dench
# ...

# %%
len(denches)
# Out:
# 52

# %% [markdown]
# ### List the supporting roles (having n=2) played by Cary Grant in the 1940s, in order by year.

# %%
cast[(cast.year >= 1940) & (cast.year <= 1949) & (cast.name == "Cary Grant") & (cast.n == 2)]
# Out:
#                    title  year        name   type    character  n
# 789995  My Favorite Wife  1940  Cary Grant  actor         Nick  2
# 790005    Penny Serenade  1941  Cary Grant  actor  Roger Adams  2

# %% [markdown]
# ### List the leading roles that Cary Grant played in the 1940s in order by year.

# %%
cast[(cast.year >= 1940) & (cast.year <= 1949) & (cast.name == "Cary Grant") & (cast.n == 1)].sort_values('year')
# Out:
#                                        title  year        name   type  \
# 790020               The Howards of Virginia  1940  Cary Grant  actor
# 789977                       His Girl Friday  1940  Cary Grant  actor
# 790022                The Philadelphia Story  1940  Cary Grant  actor
# 790010                             Suspicion  1941  Cary Grant  actor
# 790024                  The Talk of the Town  1942  Cary Grant  actor
# 790001                 Once Upon a Honeymoon  1942  Cary Grant  actor
# 789968                     Destination Tokyo  1943  Cary Grant  actor
# 789993                             Mr. Lucky  1943  Cary Grant  actor
# 789994                             Mr. Lucky  1943  Cary Grant  actor
# 790002                      Once Upon a Time  1944  Cary Grant  actor
# 789960                  Arsenic and Old Lace  1944  Cary Grant  actor
# 789997             None But the Lonely Heart  1944  Cary Grant  actor
# ...

# %% [markdown]
# ### How many roles were available for actors in the 1950s?

# %%
roles = cast[(cast.year >= 1950) & (cast.year <= 1959) & (cast.type == 'actor')]
roles
# Out:
#                                    title  year                  name   type  \
# 60                       Fire Down Below  1957  'Stretch' Cox Troupe  actor
# 62                    Dorp aan de rivier  1958         Frans 't Hoen  actor
# 104                       Die Todesarena  1953      Die 3 Motorellos  actor
# 230                     Palletoori Pilla  1950        Subba Rao A.V.  actor
# 231          Sri Kalahastiswara Mahatyam  1954        Subba Rao A.V.  actor
# 243                        Brudebuketten  1953             Per Aabel  actor
# 247                 The President's Lady  1953          Linus Aaberg  actor
# 304                     Bigger Than Life  1956             Dee Aaker  actor
# 305                   Mister Scoutmaster  1953             Dee Aaker  actor
# 306            Spin and Marty: The Movie  1955             Dee Aaker  actor
# 307              The Kid from Left Field  1953             Dee Aaker  actor
# ...

# %%
len(roles)
# Out:
# 150124

# %% [markdown]
# ### How many roles were avilable for actresses in the 1950s?

# %%
len(cast[(cast.year >= 1950) & (cast.year <= 1959) & (cast.type == 'actress')])
# Out:
# 54588

# %% [markdown]
# ### How many leading roles (n=1) were available from the beginning of film history through 1980?

# %%
leads = cast[(cast.year <= 1980) & (cast.n == 1)]
leads
# Out:
#                                                      title  year  \
# 240                                           En glad gutt  1932
# 917                                  Batman Fights Dracula  1967
# 918                                  Batman Fights Dracula  1967
# 922                                            Mighty Rock  1969
# 1001                              Ar Daijero, Rom agar var  1975
# 1006                                     Didi mtsvane veli  1967
# 1011                                             Kvarkvare  1978
# 1018                                    Pirveli mertskhali  1975
# 1021                             Sinatle chvens panjrebshi  1969
# 1026                                       Tsimbireli papa  1974
# 1033                                      Glakhis naambobi  1961
# 1098                                         Il pap'occhio  1980
# 1242                               Athkiya' laken aghbiya'  1980
# ...

# %%
len(leads)
# Out:
# 61979

# %% [markdown]
# ### How many non-leading roles were available through from the beginning of film history through 1980?

# %%
others = cast[(cast.year <= 1980) & (cast.n != 1)]
others
# Out:
#                                             title  year  \
# 25                                   Los tarantos  1963
# 28                                   Los tarantos  1963
# 35       Been Down So Long It Looks Like Up to Me  1971
# 36                         I Wanna Hold Your Hand  1978
# 37                    That's the Way of the World  1975
# 48                In the Land of the Head Hunters  1914
# 50                                   Los tarantos  1963
# 51                                   Los tarantos  1963
# 60                                Fire Down Below  1957
# 61                                   De zaak M.P.  1960
# 62                             Dorp aan de rivier  1958
# 90                                    Wild Wheels  1969
# 94                                  C.B. Hustlers  1976
# 99                              Atemlos vor Liebe  1970
# 101                           Thunder in Carolina  1960
# 104                                Die Todesarena  1953
# ...

# %%
len(others)
# Out:
# 1061496

# %% [markdown]
# ### How many roles through 1980 were minor enough that they did not warrant a numeric "n" rank?

# %%
len(cast[(cast.year <= 1980) & (cast.n.isnull())])
# Out:
# 422512
